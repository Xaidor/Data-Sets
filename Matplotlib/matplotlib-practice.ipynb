# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [2,4,5,8,13]
y = [30, 32, 37, 55, 60]

# %%
plt.plot(x,y);

# %%
fig, ax = plt.subplots();

# %%
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
x = [34, 77, 21, 54, 9]
y = [9, 45, 89, 66, 4]

fig, ax = plt.subplots()

ax.plot(x,y)
ax.set(title="Company Employee Growth",
      xlabel="Years",
      ylabel="Number of Employees")

fig.savefig("images/matplotlib-fig-practice.png");

# %%
x = np.linspace(0,10,100)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
fav_food_prices = {"Tacos": 14,
                   "Burger": 12,
                   "Sushi": 30}

# %%
fig, ax = plt.subplots()
ax.bar(fav_food_prices.keys(), fav_food_prices.values());
ax.set(title="My Favorite Foods",
      xlabel="Favorite Foods",
      ylabel="Price");

# %%
fig, ax = plt.subplots()
ax.barh(fav_food_prices.keys(), fav_food_prices.values())
ax.set(title="My Favorite Foods",
      xlabel="Prices",
      ylabel="Favorite Foods");

# %%
x = np.random.randn(1000)
x[:10]
# Out:
# array([-0.14120023,  1.34144125,  0.42285645,  1.32086544,  2.15681629,
#         0.06205477,  1.15465091,  1.37196719, -0.15427794, -0.59742078])

# %%
plt.hist(x);

# %%
x = np.random.random(1000)
x[:10]
# Out:
# array([0.66536968, 0.77215526, 0.7255584 , 0.59315072, 0.76199192,
#        0.23318915, 0.19224935, 0.28586102, 0.76301152, 0.40260627])

# %%
plt.hist(x);

# %%
fig, ax = plt.subplots(nrows= 2,
                       ncols= 2,
                       figsize= (10,6));

# %%
fig, ax = plt.subplots(figsize= (10,5),
                       nrows= 2,
                       ncols= 2)
ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(fav_food_prices.keys(), fav_food_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
plt.plot(car_sales["Price"]);

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 car_sales["Price"].plot()
#
# File ~/Desktop/Demo_Projects/env/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Desktop/Demo_Projects/env/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
car_sales["Price"] = car_sales["Price"].str.replace("$", "").str.replace(",", "").str.replace(".", "")
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
#In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales["Sales Date"] = pd.date_range("13/6/2025", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales Sales Date
# 0  Toyota  White         150043      4   4000         4000 2025-06-13
# 1   Honda    Red          87899      4   5000         9000 2025-06-14
# 2  Toyota   Blue          32549      3   7000        16000 2025-06-15
# 3     BMW  Black          11179      5  22000        38000 2025-06-16
# 4  Nissan  White         213095      4   3500        41500 2025-06-17
# 5  Toyota  Green          99213      4   4500        46000 2025-06-18
# 6   Honda   Blue          45698      4   7500        53500 2025-06-19
# 7   Honda   Blue          54738      4   7000        60500 2025-06-20
# 8  Toyota  White          60000      4   6250        66750 2025-06-21
# 9  Nissan  White          31600      4   9700        76450 2025-06-22

# %%
car_sales.plot("Sales Date", "Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales.plot("Odometer (KM)", "Price", kind="scatter");

# %%
X = np.random.rand(10,4)

# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']
df = pd.DataFrame(X, columns=["a", "b", "c", "d"])

df.plot(kind="bar");

# %%
car_sales.plot("Make", "Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales.plot("Odometer (KM)", kind="hist");

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(subplots=True, figsize=(10,30));
